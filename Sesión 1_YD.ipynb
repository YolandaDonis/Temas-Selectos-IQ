# %%
a = 1
b = 3.3
c = "uno"
d =  True

lista1 = [1,2,3,4,5]
lista2 = ["uno", "dos", "tres"]
lista3 = [1.1,2.2,3.3,4.4]
lista4 = [True, False]

("Cambio de un dato por otro")
lista1[1] = 6

# %%
lista1, lista2, lista3
# Out:
# ([1, 6, 3, 4, 5], ['uno', 'dos', 'tres'], [1.1, 2.2, 3.3, 4.4])

# %%
lista1
# Out:
# [1, 6, 3, 4, 5]

# %%
("Lista combinada")
lista1 + lista2 + lista3
# Out:
# [1, 6, 3, 4, 5, 'uno', 'dos', 'tres', 1.1, 2.2, 3.3, 4.4]

# %% [markdown]
# Para llamar datos

# %%
lista1[3]
# Out:
# 4

# %% [markdown]
# Añadir elemento a la lista(antes y después se debe llamar la lista)

# %%
lista1.append(3)
lista1
# Out:
# [1, 6, 3, 4, 5, 3]

# %% [markdown]
# añadir varios elementos

# %%
nuevos_elementos=[9,10,11]
lista1.extend(nuevos_elementos)
lista1
# Out:
# [1, 6, 3, 4, 5, 3, 9, 10, 11]

# %% [markdown]
# remover un dato

# %%
lista1.remove(3)
lista1
# Out:
# [1, 6, 4, 5, 3, 9, 10, 11]

# %%
e = "Buenos días"
e
# Out:
# 'Buenos días'

# %% [markdown]
# reemplazar palabra de un texto

# %%
e.replace("días", "tardes")
# Out:
# 'Buenos tardes'

# %% [markdown]
# Para que reconozca un numero como texto

# %%
f = 33.3
h = str(f)
h
# Out:
# '33.3'

# %%
i = "saludos"
j = " cordiales"
i + j
# Out:
# 'saludos cordiales'

# %% [markdown]
# Datos booleanos

# %%
Luis = 7
Jorge = 10
Luis > Jorge
# Out:
# False

# %%
Luis < Jorge
# Out:
# True
